# %%
import os
import glob
import pandas as pd

# %% [markdown]
# ----------------------------------
#
# #### 첫번째 오디오 특성 병합

# %%
folder_path = '/home/ubuntu/project/4.5HZ/Data/수집/audio_수집_진행/병합'

file_paths = glob.glob(os.path.join(folder_path, '*.csv'))

combined_df = pd.DataFrame()

for file_path in file_paths:
    df = pd.read_csv(file_path)
    combined_df = pd.concat([combined_df, df])

combined_df.drop_duplicates(subset='track_id', inplace=True)
combined_df.sort_values('track_id', inplace=True)

combined_filename = '/home/ubuntu/project/4.5HZ/Data/적재/적재_오디오_특성(12월20일).csv'
combined_df.to_csv(combined_filename, index=False, encoding='utf-8')

# %%
combined_df.info()
combined_df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62026 entries, 850 to 278
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      62026 non-null  float64
#  1   energy            62026 non-null  float64
#  2   music_key         62026 non-null  int64
#  3   loudness          62026 non-null  float64
#  4   music_mode        62026 non-null  int64
#  5   speechiness       62026 non-null  float64
#  6   acousticness      62026 non-null  float64
#  7   instrumentalness  62026 non-null  float64
#  8   liveness          62026 non-null  float64
#  9   valence           62026 non-null  float64
#  10  tempo             62026 non-null  float64
#  11  track_id          62026 non-null  object
#  12  duration_ms       62026 non-null  int64
#  13  time_signature    62026 non-null  int64
# dtypes: float64(9), int64(4), object(1)
# memory usage: 7.1+ MB
# (62026, 14)

# %%
folder_path = '/home/ubuntu/project/4.5HZ/Data/수집/audio_수집_진행/병합'

file_paths = glob.glob(os.path.join(folder_path, '*.csv'))

combined_df2 = pd.DataFrame()

for file_path in file_paths:
    df = pd.read_csv(file_path)
    combined_df2 = pd.concat([combined_df2, df])

combined_df2.sort_values('track_id', inplace=True)

#combined_filename = '/home/ubuntu/project/4.5HZ/Data/적재/적재_오디오_특성(12월20일).csv'
#combined_df.to_csv(combined_filename, index=False)

# %%
combined_df2.info()
combined_df2.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66204 entries, 850 to 278
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      66204 non-null  float64
#  1   energy            66204 non-null  float64
#  2   music_key         66204 non-null  int64
#  3   loudness          66204 non-null  float64
#  4   music_mode        66204 non-null  int64
#  5   speechiness       66204 non-null  float64
#  6   acousticness      66204 non-null  float64
#  7   instrumentalness  66204 non-null  float64
#  8   liveness          66204 non-null  float64
#  9   valence           66204 non-null  float64
#  10  tempo             66204 non-null  float64
#  11  track_id          66204 non-null  object
#  12  duration_ms       66204 non-null  int64
#  13  time_signature    66204 non-null  int64
# dtypes: float64(9), int64(4), object(1)
# memory usage: 7.6+ MB
# (66204, 14)

# %% [markdown]
# ----------------------------------
#
# #### 두번째 트랙 특성 병합

# %%
 # 9개 장르만 1차 처리
folder_path = '/home/ubuntu/project/4.5HZ/Data/정리/track_수집_완료_병합/병합_전_데이터/사용 장르 10개'

file_paths = glob.glob(os.path.join(folder_path, '*.csv'))

track_df = pd.DataFrame()

for file_path in file_paths:
    df = pd.read_csv(file_path)
    track_df = pd.concat([track_df, df])

track_df = track_df.drop_duplicates(subset='track_id')

track_df['release_date'] = pd.to_datetime(track_df['release_date'], errors='coerce')

mask = (track_df['release_date'].dt.year >= 2019) & (track_df['release_date'].dt.year <= 2023)
track_df = track_df.loc[mask]

track_df.loc[track_df['release_date'].dt.month.isnull(), 'release_date'] = track_df['release_date'] + pd.offsets.DateOffset(month=1, day=1)

track_df = track_df.sort_values(by='track_id')

combined_filename = '/home/ubuntu/project/4.5HZ/Data/적재/적재_트랙_특성_장르9개.csv'
track_df.to_csv(combined_filename, index=False, encoding='utf-8')
# Out:
# /tmp/ipykernel_2016/251215584.py:25: PerformanceWarning: Non-vectorized DateOffset being applied to Series or DatetimeIndex.
#   track_df.loc[track_df['release_date'].dt.month.isnull(), 'release_date'] = track_df['release_date'] + pd.offsets.DateOffset(month=1, day=1)

# %%
track_df.info()
track_df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43216 entries, 781 to 2275
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist_id         43216 non-null  object
#  1   artist_name       43216 non-null  object
#  2   track_id          43216 non-null  object
#  3   track_name        43216 non-null  object
#  4   release_date      43216 non-null  datetime64[ns]
#  5   track_popularity  43216 non-null  int64
#  6   album_image       43215 non-null  object
#  7   genres            43216 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 3.0+ MB
# (43216, 8)

# %%
file_path = '/home/ubuntu/project/4.5HZ/Data/정리/track_수집_완료_병합/병합_전_데이터/k-pop_total.csv'
track_df2 = pd.read_csv(file_path)

track_df2 = track_df2.drop_duplicates(subset='track_id')

track_df2['release_date'] = pd.to_datetime(track_df2['release_date'], errors='coerce')

track_df2.loc[track_df2['release_date'].dt.month.isnull(), 'release_date'] = track_df2['release_date'] + pd.offsets.DateOffset(month=1, day=1)

mask = (track_df2['release_date'].dt.year >= 2001) & (track_df2['release_date'].dt.year <= 2023)
track_df2 = track_df2.loc[mask]

track_df2 = track_df2.sort_values(by='track_id')

combined_filename = '/home/ubuntu/project/4.5HZ/Data/적재/적재_트랙_특성_케이팝.csv'
track_df2.to_csv(combined_filename, index=False, encoding='utf-8')

# %%
track_df2.info()
track_df2.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22059 entries, 1448 to 13518
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist_id         22059 non-null  object
#  1   artist_name       22059 non-null  object
#  2   track_id          22059 non-null  object
#  3   track_name        22059 non-null  object
#  4   release_date      22059 non-null  datetime64[ns]
#  5   track_popularity  22059 non-null  int64
#  6   album_image       22058 non-null  object
#  7   genres            22059 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 1.5+ MB
# (22059, 8)

# %%
file_path1 = '/home/ubuntu/project/4.5HZ/Data/적재/적재_트랙_특성_장르9개.csv'
file_path2 = '/home/ubuntu/project/4.5HZ/Data/적재/적재_트랙_특성_케이팝.csv'
track_df1_1 = pd.read_csv(file_path1)
track_df2_1 = pd.read_csv(file_path2)

track_df3 = pd.concat([track_df1_1, track_df2_1])

track_df3 = track_df3.drop_duplicates(subset='track_id')

track_df3 = track_df3.sort_values(by='track_id')

track_df3.info()
track_df3.shape

combined_filename = '/home/ubuntu/project/4.5HZ/Data/적재/적재_트랙(12월20일).csv'
track_df3.to_csv(combined_filename, index=False, encoding='utf-8')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60276 entries, 0 to 38771
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist_id         60276 non-null  object
#  1   artist_name       60276 non-null  object
#  2   track_id          60276 non-null  object
#  3   track_name        60276 non-null  object
#  4   release_date      60276 non-null  object
#  5   track_popularity  60276 non-null  int64
#  6   album_image       60274 non-null  object
#  7   genres            60276 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 4.1+ MB

# %% [markdown]
# ----------------------------------
#
# #### 세번째 오디오특성과 트랙데이터 누락 데이터 찾기 (누락 데이터 서로 삭제하는 방식으로 변경)

# %%
file_path1 = '/home/ubuntu/project/4.5HZ/Data/적재/적재_오디오_특성(12월20일).csv'
file_path2 = '/home/ubuntu/project/4.5HZ/Data/적재/적재_트랙(12월20일).csv'
audio_df = pd.read_csv(file_path1)
track_df = pd.read_csv(file_path2)

audio_not_in_track = set(audio_df['track_id']) - set(track_df['track_id'])
track_not_in_audio = set(track_df['track_id']) - set(audio_df['track_id'])

print(f'오디오 데이터에는 있지만 트랙 데이터에는 없는 track_id 개수: {len(audio_not_in_track)}')
print(f'오디오 데이터에는 있지만 트랙 데이터에는 없는 track_id 리스트: {list(audio_not_in_track)}')
print(f'트랙 데이터에는 있지만 오디오 데이터에는 없는 track_id 개수: {len(track_not_in_audio)}')
print(f'트랙 데이터에는 있지만 오디오 데이터에는 없는 track_id 리스트: {list(track_not_in_audio)}')
# Out:
# 오디오 데이터에는 있지만 트랙 데이터에는 없는 track_id 개수: 5131
# ...

# %%
audio_not_in_track_df = pd.DataFrame(list(audio_not_in_track), columns=['track_id'])
audio_not_in_track_df.to_csv('/home/ubuntu/project/4.5HZ/Data/적재/12월 20일_오디오_기준_트랙_누락.csv', index=False)

track_not_in_audio_df = pd.DataFrame(list(track_not_in_audio), columns=['track_id'])
track_not_in_audio_df.to_csv('/home/ubuntu/project/4.5HZ/Data/적재/12월 20일_트랙_기준_오디오_누락.csv', index=False)

# %%
file_path1 = '/home/ubuntu/project/4.5HZ/Data/적재/적재_오디오_특성(12월20일).csv'
file_path2 = '/home/ubuntu/project/4.5HZ/Data/적재/적재_트랙(12월20일).csv'
audio_df = pd.read_csv(file_path1)
track_df = pd.read_csv(file_path2)

audio_not_in_track = set(audio_df['track_id']) - set(track_df['track_id'])
track_not_in_audio = set(track_df['track_id']) - set(audio_df['track_id'])
overlap = set(audio_df['track_id']).intersection(set(track_df['track_id']))

audio_df = audio_df[~audio_df['track_id'].isin(audio_not_in_track)]
track_df = track_df[~track_df['track_id'].isin(track_not_in_audio)]

audio_df.to_csv('/home/ubuntu/project/4.5HZ/Data/적재/최종_적재_오디오_특성(12월20일).csv', index=False, encoding='utf-8')
track_df.to_csv('/home/ubuntu/project/4.5HZ/Data/적재/최종_적재_트랙(12월20일).csv', index=False, encoding='utf-8')

print(f'오디오 데이터에는 있지만 트랙 데이터에는 없는 track_id 개수: {len(audio_not_in_track)}')
print(f'오디오 데이터에는 있지만 트랙 데이터에는 없는 track_id 리스트: {list(audio_not_in_track)}')
print(f'트랙 데이터에는 있지만 오디오 데이터에는 없는 track_id 개수: {len(track_not_in_audio)}')
print(f'트랙 데이터에는 있지만 오디오 데이터에는 없는 track_id 리스트: {list(track_not_in_audio)}')
print(f'서로 중복되는 track_id 개수: {len(overlap)}')
print(f'중복되지 않는 track_id 개수: {len(audio_not_in_track) + len(track_not_in_audio)}')
# Out:
# 오디오 데이터에는 있지만 트랙 데이터에는 없는 track_id 개수: 5131
# ...

# %%
file_path1 = '/home/ubuntu/project/4.5HZ/Data/적재/최종_적재_오디오_특성(12월20일).csv'
file_path2 = '/home/ubuntu/project/4.5HZ/Data/적재/최종_적재_트랙(12월20일).csv'
audio_df = pd.read_csv(file_path1)
track_df = pd.read_csv(file_path2)

overlap = set(audio_df['track_id']).intersection(set(track_df['track_id']))
non_overlap = set(audio_df['track_id']).symmetric_difference(set(track_df['track_id']))

print(f'첫번째 비교, 서로 중복되는 track_id 개수: {len(overlap)}')
print(f'두번째 비교, 서로 중복되지 않는 track_id 개수: {len(non_overlap)}')
# Out:
# 첫번째 비교, 서로 중복되는 track_id 개수: 56895
# 두번째 비교, 서로 중복되지 않는 track_id 개수: 0

# %% [markdown]
# ----------------------------------
#
# #### 네번째 트랙데이터와 아티스트데이터 누락 데이터 찾기 (누락 데이터 서로 삭제하는 방식으로 변경)

# %%
file_path1 = '/home/ubuntu/project/4.5HZ/Data/적재/최종/최종_적재_트랙(12월20일).csv'
file_path2 = '/home/ubuntu/project/4.5HZ/Data/적재/spotify_artist.csv'
track_df = pd.read_csv(file_path1)
artist_df = pd.read_csv(file_path2)

print(f'원본 track_df shape: {track_df.shape}')
print(f'원본 artist_df shape: {artist_df.shape}')

track_df = track_df.dropna(subset=['artist_id'])
artist_df = artist_df.dropna(subset=['artist_id'])

artist_df = artist_df.drop(['Unnamed: 4', 'Unnamed: 5'], axis=1)

print(f'결측치 및 칼럼 제거 후 track_df shape: {track_df.shape}')
print(f'결측치 및 칼럼 제거 후 artist_df shape: {artist_df.shape}')

track_not_in_artist = set(track_df['artist_id']) - set(artist_df['artist_id'])
artist_not_in_track = set(artist_df['artist_id']) - set(track_df['artist_id'])

print(f'트랙 데이터에는 있지만 아티스트 데이터에는 없는 artist_id 개수: {len(track_not_in_artist)}')
print(f'트랙 데이터에는 있지만 아티스트 데이터에는 없는 artist_id 리스트: {list(track_not_in_artist)}')
print(f'아티스트 데이터에는 있지만 트랙 데이터에는 없는 artist_id 개수: {len(artist_not_in_track)}')
print(f'아티스트 데이터에는 있지만 트랙 데이터에는 없는 artist_id 리스트: {list(artist_not_in_track)}')

artist_df = artist_df[~artist_df['artist_id'].isin(artist_not_in_track)]

artist_df = artist_df.sort_values(by='artist_id')

artist_df.to_csv('/home/ubuntu/project/4.5HZ/Data/적재/최종_적재_아티스트(12월20일).csv', index=False, encoding='utf-8')
# Out:
# 원본 track_df shape: (56895, 8)
# 원본 artist_df shape: (66495, 6)
# 결측치 및 칼럼 제거 후 track_df shape: (56895, 8)
# 결측치 및 칼럼 제거 후 artist_df shape: (17334, 4)
# 트랙 데이터에는 있지만 아티스트 데이터에는 없는 artist_id 개수: 0
# 트랙 데이터에는 있지만 아티스트 데이터에는 없는 artist_id 리스트: []
# 아티스트 데이터에는 있지만 트랙 데이터에는 없는 artist_id 개수: 11599
# ...

# %%
artist_df.info()
artist_df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5735 entries, 9 to 17333
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   artist_id          5735 non-null   object
#  1   artist_name        5735 non-null   object
#  2   artist_popularity  5735 non-null   float64
#  3   artist_followers   5735 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 224.0+ KB
# (5735, 4)

# %%
file_path1 = '/home/ubuntu/project/4.5HZ/Data/적재/최종/최종_적재_아티스트(12월20일).csv'
file_path2 = '/home/ubuntu/project/4.5HZ/Data/적재/최종/최종_적재_트랙(12월20일).csv'
artist_df = pd.read_csv(file_path1)
track_df = pd.read_csv(file_path2)

common_artist_id = set(artist_df['artist_id']) & set(track_df['artist_id'])

artist_not_in_track = set(artist_df['artist_id']) - set(track_df['artist_id'])
track_not_in_artist = set(track_df['artist_id']) - set(artist_df['artist_id'])

print(f'아티스트 데이터와 트랙 데이터에서 중복되는 artist_id 개수: {len(common_artist_id)}')
print(f'아티스트 데이터에는 있지만 트랙 데이터에는 없는 artist_id 개수: {len(artist_not_in_track)}')
print(f'트랙 데이터에는 있지만 아티스트 데이터에는 없는 artist_id 개수: {len(track_not_in_artist)}')
# Out:
# 아티스트 데이터와 트랙 데이터에서 중복되는 artist_id 개수: 5735
# 아티스트 데이터에는 있지만 트랙 데이터에는 없는 artist_id 개수: 0
# 트랙 데이터에는 있지만 아티스트 데이터에는 없는 artist_id 개수: 0

# %% [markdown]
# ----------------------------------
#
# #### 다번째 파일 적재를 위해 칼럼 순서 및 칼럼명 변경

# %% [markdown]
# ##### 아티스트

# %%
file_path = '/home/ubuntu/project/4.5HZ/Data/적재/최종/최종_적재_아티스트(12월20일).csv'
artist_df_5 = pd.read_csv(file_path)
artist_df_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5735 entries, 0 to 5734
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   artist_id          5735 non-null   object
#  1   artist_name        5735 non-null   object
#  2   artist_popularity  5735 non-null   float64
#  3   artist_followers   5735 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 179.3+ KB

# %%
artist_df_5.rename(columns={'artist_popularity': 'popularity', 'artist_followers': 'followers'}, inplace=True)

print(artist_df_5.columns)

output_path = '/home/ubuntu/project/4.5HZ/Data/완성/최종완성_적재_아티스트(12월20일).csv'
artist_df_5.to_csv(output_path, index=False)
# Out:
# Index(['artist_id', 'artist_name', 'popularity', 'followers'], dtype='object')

# %% [markdown]
# ##### 트랙

# %%
file_path = '/home/ubuntu/project/4.5HZ/Data/적재/최종/최종_적재_트랙(12월20일).csv'
track_df_5 = pd.read_csv(file_path)

track_df_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56895 entries, 0 to 56894
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist_id         56895 non-null  object
#  1   artist_name       56895 non-null  object
#  2   track_id          56895 non-null  object
#  3   track_name        56895 non-null  object
#  4   release_date      56895 non-null  object
#  5   track_popularity  56895 non-null  int64
#  6   album_image       56893 non-null  object
#  7   genres            56895 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 3.5+ MB

# %%
track_df_5 = track_df_5[['artist_name', 'track_id', 'track_name', 'release_date', 'track_popularity', 'album_image', 'genres', 'artist_id']]

track_df_5.rename(columns={'artist_id': 'ARTIST_ID', 'album_image': 'track_picture_url'}, inplace=True)

print(track_df_5.columns)

output_path = '/home/ubuntu/project/4.5HZ/Data/완성/최종완성_적재_트랙(12월20일).csv'
track_df_5.to_csv(output_path, index=False)
# Out:
# Index(['artist_name', 'track_id', 'track_name', 'release_date',
#        'track_popularity', 'track_picture_url', 'genres', 'ARTIST_ID'],
#       dtype='object')

# %% [markdown]
# ##### 오디오 특성

# %%
file_path = '/home/ubuntu/project/4.5HZ/Data/적재/최종/최종_적재_오디오_특성(12월20일).csv'
audio_features_df_5 = pd.read_csv(file_path)
audio_features_df_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56895 entries, 0 to 56894
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      56895 non-null  float64
#  1   energy            56895 non-null  float64
#  2   music_key         56895 non-null  int64
#  3   loudness          56895 non-null  float64
#  4   music_mode        56895 non-null  int64
#  5   speechiness       56895 non-null  float64
#  6   acousticness      56895 non-null  float64
#  7   instrumentalness  56895 non-null  float64
#  8   liveness          56895 non-null  float64
#  9   valence           56895 non-null  float64
#  10  tempo             56895 non-null  float64
#  11  track_id          56895 non-null  object
#  12  duration_ms       56895 non-null  int64
#  13  time_signature    56895 non-null  int64
# dtypes: float64(9), int64(4), object(1)
# memory usage: 6.1+ MB

# %%
audio_features_df_5 = audio_features_df_5[['danceability', 'energy', 'music_key', 'loudness', 'music_mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature', 'track_id']]

audio_features_df_5.rename(columns={'track_id': 'TRACK_ID'}, inplace=True)

print(audio_features_df_5.columns)

output_path = '/home/ubuntu/project/4.5HZ/Data/완성/최종완성_적재_오디오특성(12월20일).csv'
audio_features_df_5.to_csv(output_path, index=False)
# Out:
# Index(['danceability', 'energy', 'music_key', 'loudness', 'music_mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature', 'TRACK_ID'],
#       dtype='object')

# %% [markdown]
# ----------------------------------
#
# #### 여번째 데이터 적재

# %%
file_path = '/home/ubuntu/project/4.5HZ/Data/완성/최종완성_적재_아티스트(12월20일).csv'
test_1 = pd.read_csv(file_path)

file_path2 = '/home/ubuntu/project/4.5HZ/Data/완성/최종완성_적재_트랙(12월20일).csv'
test_2 = pd.read_csv(file_path2)

file_path3 = '/home/ubuntu/project/4.5HZ/Data/완성/최종완성_적재_오디오특성(12월20일).csv'
test_3 = pd.read_csv(file_path3)


test_1.info()
test_1.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5735 entries, 0 to 5734
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artist_id    5735 non-null   object
#  1   artist_name  5735 non-null   object
#  2   popularity   5735 non-null   float64
#  3   followers    5735 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 179.3+ KB
# (5735, 4)

# %%
test_2.info()
test_2.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56895 entries, 0 to 56894
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   artist_name        56895 non-null  object
#  1   track_id           56895 non-null  object
#  2   track_name         56895 non-null  object
#  3   release_date       56895 non-null  object
#  4   track_popularity   56895 non-null  int64
#  5   track_picture_url  56893 non-null  object
#  6   genres             56895 non-null  object
#  7   ARTIST_ID          56895 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 3.5+ MB
# (56895, 8)

# %%
test_3.info()
test_3.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56895 entries, 0 to 56894
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      56895 non-null  float64
#  1   energy            56895 non-null  float64
#  2   music_key         56895 non-null  int64
#  3   loudness          56895 non-null  float64
#  4   music_mode        56895 non-null  int64
#  5   speechiness       56895 non-null  float64
#  6   acousticness      56895 non-null  float64
#  7   instrumentalness  56895 non-null  float64
#  8   liveness          56895 non-null  float64
#  9   valence           56895 non-null  float64
#  10  tempo             56895 non-null  float64
#  11  duration_ms       56895 non-null  int64
#  12  time_signature    56895 non-null  int64
#  13  TRACK_ID          56895 non-null  object
# dtypes: float64(9), int64(4), object(1)
# memory usage: 6.1+ MB
# (56895, 14)

# %%
file_path4 = '/home/ubuntu/project/4.5HZ/Data/완성/테스트/최종완성_적재_아티스트(12월20일).csv'
test_4 = pd.read_csv(file_path4)

file_path5 = '/home/ubuntu/project/4.5HZ/Data/완성/테스트/최종완성_적재_트랙(12월20일).csv'
test_5 = pd.read_csv(file_path5)

file_path6 = '/home/ubuntu/project/4.5HZ/Data/완성/테스트/최종완성_적재_오디오특성(12월20일).csv'
test_6 = pd.read_csv(file_path6)


test_4.info()
test_4.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5735 entries, 0 to 5734
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artist_id    5735 non-null   object
#  1   artist_name  5735 non-null   object
#  2   popularity   5735 non-null   float64
#  3   followers    5735 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 179.3+ KB
# (5735, 4)

# %%
test_5.info()
test_5.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56895 entries, 0 to 56894
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   artist_name        56895 non-null  object
#  1   track_id           56895 non-null  object
#  2   track_name         56895 non-null  object
#  3   release_date       56895 non-null  object
#  4   track_popularity   56895 non-null  int64
#  5   track_picture_url  56893 non-null  object
#  6   genres             56895 non-null  object
#  7   ARTIST_ID          56895 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 3.5+ MB
# (56895, 8)

# %%
test_6.info()
test_6.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56895 entries, 0 to 56894
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      56895 non-null  float64
#  1   energy            56895 non-null  float64
#  2   music_key         56895 non-null  int64
#  3   loudness          56895 non-null  float64
#  4   music_mode        56895 non-null  int64
#  5   speechiness       56895 non-null  float64
#  6   acousticness      56895 non-null  float64
#  7   instrumentalness  56895 non-null  float64
#  8   liveness          56895 non-null  float64
#  9   valence           56895 non-null  float64
#  10  tempo             56895 non-null  float64
#  11  duration_ms       56895 non-null  int64
#  12  time_signature    56895 non-null  int64
#  13  TRACK_ID          56895 non-null  object
# dtypes: float64(9), int64(4), object(1)
# memory usage: 6.1+ MB
# (56895, 14)

# %%
# instrumentalness
# insrumentalness

# %%
import pandas as pd

# csv 파일 불러오기
file_path1 = '/home/ubuntu/project/4.5HZ/Data/적재/12월 19일 오디오 특성 데이터 누락.csv'
file_path2 = '/home/ubuntu/project/4.5HZ/Data/적재/12월 19일 트랙 데이터 누락.csv'
file_path3 = '/home/ubuntu/project/4.5HZ/Data/적재/12월 20일_오디오_기준_트랙_누락.csv'
file_path4 = '/home/ubuntu/project/4.5HZ/Data/적재/12월 20일_트랙_기준_오디오_누락.csv'
audio_19_df = pd.read_csv(file_path1)
track_19_df = pd.read_csv(file_path2)
audio_20_df = pd.read_csv(file_path3)
track_20_df = pd.read_csv(file_path4)

# 'TRACK_ID'를 'track_id'로 변경
track_19_df = track_19_df.rename(columns={'TRACK_ID': 'track_id'})

# 첫번째 비교
overlap1 = set(audio_20_df['track_id']).intersection(set(track_19_df['track_id']))
track_19_not_in_audio_20 = set(track_19_df['track_id']) - set(audio_20_df['track_id'])

# 두번째 비교
overlap2 = set(track_20_df['track_id']).intersection(set(audio_19_df['track_id']))
audio_19_not_in_track_20 = set(audio_19_df['track_id']) - set(track_20_df['track_id'])

# 결과 출력
print(f'첫번째 비교 중복 개수: {len(overlap1)}')
print(f'19일 트랙 데이터에는 있지만 20일 오디오 데이터에는 없는 track_id 개수: {len(track_19_not_in_audio_20)}')
print(f'19일 트랙 데이터에는 있지만 20일 오디오 데이터에는 없는 track_id 리스트: {list(track_19_not_in_audio_20)}')

print(f'두번째 비교 중복 개수: {len(overlap2)}')
print(f'19일 오디오 데이터에는 있지만 20일 트랙 데이터에는 없는 track_id 개수: {len(audio_19_not_in_track_20)}')
print(f'19일 오디오 데이터에는 있지만 20일 트랙 데이터에는 없는 track_id 리스트: {list(audio_19_not_in_track_20)}')
# Out:
# 첫번째 비교 중복 개수: 4303
# 19일 트랙 데이터에는 있지만 20일 오디오 데이터에는 없는 track_id 개수: 0
# 19일 트랙 데이터에는 있지만 20일 오디오 데이터에는 없는 track_id 리스트: []
# 두번째 비교 중복 개수: 3381
# 19일 오디오 데이터에는 있지만 20일 트랙 데이터에는 없는 track_id 개수: 1086
# ...

# %%
import pandas as pd

# csv 파일 불러오기
file_path1 = '/home/ubuntu/project/4.5HZ/Data/적재/12월 19일 오디오 특성 데이터 누락.csv'
file_path2 = '/home/ubuntu/project/4.5HZ/Data/적재/12월 19일 트랙 데이터 누락.csv'
file_path3 = '/home/ubuntu/project/4.5HZ/Data/적재/12월 20일_오디오_기준_트랙_누락.csv'
file_path4 = '/home/ubuntu/project/4.5HZ/Data/적재/12월 20일_트랙_기준_오디오_누락.csv'
audio_19_df = pd.read_csv(file_path1)
track_19_df = pd.read_csv(file_path2)
audio_20_df = pd.read_csv(file_path3)
track_20_df = pd.read_csv(file_path4)

# 'TRACK_ID'를 'track_id'로 변경
track_19_df = track_19_df.rename(columns={'TRACK_ID': 'track_id'})

# 첫번째 비교
overlap1 = set(track_19_df['track_id']).intersection(set(audio_20_df['track_id']))
audio_20_not_in_track_19 = set(audio_20_df['track_id']) - set(track_19_df['track_id'])

# 두번째 비교
overlap2 = set(audio_19_df['track_id']).intersection(set(track_20_df['track_id']))
track_20_not_in_audio_19 = set(track_20_df['track_id']) - set(audio_19_df['track_id'])

# 결과 출력
print(f'첫번째 비교 중복 개수: {len(overlap1)}')
print(f'20일 오디오 데이터에는 있지만 19일 트랙 데이터에는 없는 track_id 개수: {len(audio_20_not_in_track_19)}')
print(f'20일 오디오 데이터에는 있지만 19일 트랙 데이터에는 없는 track_id 리스트: {list(audio_20_not_in_track_19)}')

print(f'두번째 비교 중복 개수: {len(overlap2)}')
print(f'20일 트랙 데이터에는 있지만 19일 오디오 데이터에는 없는 track_id 개수: {len(track_20_not_in_audio_19)}')
print(f'20일 트랙 데이터에는 있지만 19일 오디오 데이터에는 없는 track_id 리스트: {list(track_20_not_in_audio_19)}')
# Out:
# 첫번째 비교 중복 개수: 4303
# 20일 오디오 데이터에는 있지만 19일 트랙 데이터에는 없는 track_id 개수: 828
# ...
